# %%
from skimage.feature import hog
from skimage.io import imread
from skimage.transform import resize
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier # KNeighborsClassifier
from sklearn.metrics import classification_report
import numpy as np
import glob
import kagglehub
from skimage.color import rgb2gray

# %%
# !kaggle datasets download -d ashishsaxena2209/animal-image-datasetdog-cat-and-panda
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ashishsaxena2209/animal-image-datasetdog-cat-and-panda
# License(s): unknown
# Downloading animal-image-datasetdog-cat-and-panda.zip to /content
# 100% 375M/376M [00:06<00:00, 79.0MB/s]
# 100% 376M/376M [00:06<00:00, 58.5MB/s]

# %%
import zipfile

with zipfile.ZipFile("animal-image-datasetdog-cat-and-panda.zip", 'r') as zip_ref:
    zip_ref.extractall("/content/animal_dataset")

# %%
# Load dataset

path = "/content/animal_dataset/animals/"
animal_images = []

animal_labels = []

for animal_type in ['cats', 'dogs', 'panda']:

  for image_path in glob.glob(f'{path}/{animal_type}/*.jpg'):

    image = imread(image_path)
    image = resize(image, (128, 64)) # Resize images to a fixed size
    animal_images.append(image)
    animal_labels.append(animal_type)

# Extract HOG features
hog_features = [hog(rgb2gray(image), pixels_per_cell=(8, 8), cells_per_block=(2, 2),
visualize=False) for image in animal_images]

hog_features = np.array(hog_features)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-ddfe6ead20c6> in <cell line: 18>()
#      16
#      17 # Extract HOG features
# ---> 18 hog_features = [hog(rgb2gray(image), pixels_per_cell=(8, 8), cells_per_block=(2, 2),
#      19 visualize=False) for image in animal_images]
#      20
#
# <ipython-input-10-ddfe6ead20c6> in <listcomp>(.0)
#      16
#      17 # Extract HOG features
# ---> 18 hog_features = [hog(rgb2gray(image), pixels_per_cell=(8, 8), cells_per_block=(2, 2),
#      19 visualize=False) for image in animal_images]
#      20
#
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py in fixed_func(*args, **kwargs)
#     436
#     437             if channel_axis is None:
# --> 438                 return func(*args, **kwargs)
#     439
#     440             # TODO: convert scalars to a tuple in anticipation of eventually
#
# /usr/local/lib/python3.10/dist-packages/skimage/color/colorconv.py in rgb2gray(rgb, channel_axis)
#     980     >>> img_gray = rgb2gray(img)
#     981     """
# --> 982     rgb = _prepare_colorarray(rgb)
#     983     coeffs = np.array([0.2125, 0.7154, 0.0721], dtype=rgb.dtype)
#     984     return rgb @ coeffs
#
# /usr/local/lib/python3.10/dist-packages/skimage/color/colorconv.py in _prepare_colorarray(arr, force_copy, channel_axis)
#     168             f'got {arr.shape}'
#     169         )
# --> 170         raise ValueError(msg)
#     171
#     172     float_dtype = _supported_float_type(arr.dtype)
#
# ValueError: the input array must have size 3 along `channel_axis`, got (128, 64)

# %%
# Prepare labels
labels = np.array(animal_labels)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(hog_features, labels,
test_size=0.2, random_state=42)

# Train a classifier using KNN
knn_clf = KNeighborsClassifier(n_neighbors=5) # Using KNN with n_neighbors set to 5
knn_clf.fit(X_train, y_train)

# Predict and evaluate
y_pred = knn_clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-2ca5d23e280a> in <cell line: 5>()
#       3
#       4 # Split dataset
# ----> 5 X_train, X_test, y_train, y_test = train_test_split(hog_features, labels,
#       6 test_size=0.2, random_state=42)
#       7
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     211                     )
#     212                 ):
# --> 213                     return func(*args, **kwargs)
#     214             except InvalidParameterError as e:
#     215                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2783
#    2784     n_samples = _num_samples(arrays[0])
# -> 2785     n_train, n_test = _validate_shuffle_split(
#    2786         n_samples, test_size, train_size, default_test_size=0.25
#    2787     )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2413
#    2414     if n_train == 0:
# -> 2415         raise ValueError(
#    2416             "With n_samples={}, test_size={} and train_size={}, the "
#    2417             "resulting train set will be empty. Adjust any of the "
#
# ValueError: With n_samples=0, test_size=0.2 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.
